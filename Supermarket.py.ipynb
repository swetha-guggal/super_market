# %%
 #-*- coding: utf-8 -*-
"""supermarket.ipynb

Automatically generated by Colaboratory.

Original file is located at
    https://colab.research.google.com/drive/1OPp7Vsia2NrENSM-g3SQ2bHukBl3mJzV
"""

from typing import TextIO
from datetime import datetime
Name = input("PLEASE ENTER YOUR NAME:")
#list of items
lists = '''
   Rice       Rs 50/kg
   wheat      Rs 250/bag
   suji       Rs 50/kg
   boost      Rs 300/pkt
   oil        Rs 190/pkt
   maggie     Rs 100/pkt
   colgate    Rs 80/each
   '''
price       =  0
pricelist =   []
Total_price =  0
Final_price =  0
item_list =    []
qty_list =     []
plist = []
#rates for item

items = {"Rice":50,"wheat":250,"suji":50,"boost":300,"oil":190,"maggie":100,"colgate":80}
option = int(input("For list of items press 1:"))
if option == 1:
   print(lists)
for i in range(len(items)):
  inp1 = int(input("If you want to buy press 1 and 2 to exit"))
  if inp1 == 2:
    break
  if  inp1 ==1:
    item = input("plese enter item you want:")
    quantity = int(input("please enter quantity of your item:"))
    if item in items.keys():
      price = quantity*(items[item])
      pricelist.append((item,quantity,items,price))
      Total_price+=price
      item_list.append(item)
      qty_list.append(quantity)
      plist.append(price)
      GST = (Total_price*5)/100
      Final_price = GST+Total_price
    else:
      print("Entered Item Is not Available:")
  else:
      print("You have entered wrong number")
  inp = input("Would you liketo bill the Items yes or no")
  if inp == "yes":
    pass
    if Final_price!=0:
      print(250*"=","Vijay super market",25*"=")
      print(28*"=","HYDERABD")
      print("Name",Name,40*" ","Date",datetime.now())
      print(75*"-")
      print("sno",8*" ","items",8*" ",'Quantity',8*" ",'price')

      for i in range(len(plist)):
        print(i,5*' ',5*' ',item_list[i],8*' ',qty_list[i],15*' ',plist[i])


      print(75*'=')
      print(50*'=',"TotalAmount","Rs",Total_price)
      print("GST Amount",50*' ',"Rs",GST)
      print(75*'-')
      print(50*' ','FINAL AMOUNT','Rs',Final_price)
      print(75*'-')
      print(20*' ',"Thankyou For Visiting")
      print(75*'-')
# Out:
# PLEASE ENTER YOUR NAME:swetha
# For list of items press 1:1
#
#   Rice       Rs 50/kg
#   wheat      Rs 250/bag
#   suji       Rs 50/kg
#   boost      Rs 300/pkt
#   oil        Rs 190/pkt
#   maggie     Rs 100/pkt
#   colgate    Rs 80/each
#
# If you want to buy press 1 and 2 to exit1
# plese enter item you want:Rice
# please enter quantity of your item:2
# Would you liketo bill the Items yes or noyes
# ========================================================================================================================================================================================================================================================== Vijay super market =========================
# ============================ HYDERABD
# Name swetha                                          Date 2023-09-01 11:51:02.334610
# ---------------------------------------------------------------------------
# sno          items          Quantity          price
# ...
